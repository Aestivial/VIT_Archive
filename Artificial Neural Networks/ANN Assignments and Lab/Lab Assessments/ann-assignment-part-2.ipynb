# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import pandas as ps

# %%
input_file = 'Dataset/airlines_delay.csv'

# %%
data = pd.read_csv(input_file, index_col='Flight')

# %%
data.head()
# Out:
#           Time  Length Airline AirportFrom AirportTo  DayOfWeek  Class
# Flight
# 2313.0  1296.0   141.0      DL         ATL       HOU          1      0
# 6948.0   360.0   146.0      OO         COS       ORD          4      0
# 1247.0  1170.0   143.0      B6         BOS       CLT          3      0
# 31.0    1410.0   344.0      US         OGG       PHX          6      0
# 563.0    692.0    98.0      FL         BMI       ATL          4      0

# %%
airport_encoding = dict((j,i) for i,j in enumerate(set(data['AirportFrom']).union(set(data['AirportTo']))))

# %%
airport_encoding
# Out:
# {'VLD': 0,
#  'ACY': 1,
#  'GPT': 2,
#  'CHO': 3,
#  'GCC': 4,
#  'ABE': 5,
#  'BLI': 6,
#  'CLD': 7,
#  'XNA': 8,
#  'TVC': 9,
#  'DSM': 10,
#  'KOA': 11,
#  'PIE': 12,
#  'ITH': 13,
#  'EAU': 14,
#  'IAH': 15,
#  'ACT': 16,
#  'PSG': 17,
#  'PHL': 18,
#  'MSN': 19,
#  'MKE': 20,
#  'BGM': 21,
#  'TUL': 22,
#  'BIL': 23,
#  'LAN': 24,
#  'LGB': 25,
#  'SWF': 26,
#  'BIS': 27,
#  'LMT': 28,
#  'DLH': 29,
#  'IAD': 30,
#  'TYS': 31,
#  'SCE': 32,
#  'DAY': 33,
#  'HOU': 34,
#  'AUS': 35,
#  'MMH': 36,
#  'GNV': 37,
#  'ELM': 38,
#  'MCI': 39,
#  'BDL': 40,
#  'SAF': 41,
#  'JFK': 42,
#  'FAR': 43,
#  'BUR': 44,
#  'CDC': 45,
#  'FLO': 46,
#  'DEN': 47,
#  'PIH': 48,
#  'SBN': 49,
#  'FLG': 50,
#  'SGF': 51,
#  'TXK': 52,
#  'ADK': 53,
#  'SNA': 54,
#  'GRB': 55,
#  'AMA': 56,
#  'CDV': 57,
#  'HRL': 58,
#  'SMF': 59,
#  'MSO': 60,
#  'AVP': 61,
#  'SEA': 62,
#  'CHA': 63,
#  'PIT': 64,
#  'JAN': 65,
#  'MOT': 66,
#  'OGG': 67,
#  'SHV': 68,
#  'RDU': 69,
#  'RDM': 70,
#  'DCA': 71,
#  'MDT': 72,
#  'RNO': 73,
#  'EKO': 74,
#  'LIT': 75,
#  'SJC': 76,
#  'PSE': 77,
#  'FAI': 78,
#  'LIH': 79,
#  'UTM': 80,
#  'BRO': 81,
#  'ITO': 82,
#  'SRQ': 83,
#  'RSW': 84,
#  'ABY': 85,
#  'BMI': 86,
#  'RKS': 87,
#  'PVD': 88,
#  'LRD': 89,
#  'STL': 90,
#  'PBI': 91,
#  'BQN': 92,
#  'ATL': 93,
#  'ONT': 94,
#  'PWM': 95,
#  'MSY': 96,
#  'FAY': 97,
#  'HPN': 98,
#  'ABQ': 99,
#  'JAX': 100,
#  'ABR': 101,
#  'MGM': 102,
#  'GTF': 103,
#  'FAT': 104,
#  'CMH': 105,
#  'GRR': 106,
#  'MTJ': 107,
#  'LGA': 108,
#  'MHT': 109,
#  'FCA': 110,
#  'SMX': 111,
#  'PAH': 112,
#  'AVL': 113,
#  'ELP': 114,
#  'DBQ': 115,
#  'EVV': 116,
#  'RAP': 117,
#  'SBA': 118,
#  'ROC': 119,
#  'SBP': 120,
#  'FNT': 121,
#  'LWS': 122,
#  'LFT': 123,
#  'AEX': 124,
#  'CAE': 125,
#  'CHS': 126,
#  'EUG': 127,
#  'FSM': 128,
#  'PLN': 129,
#  'BWI': 130,
#  'OME': 131,
#  'LBB': 132,
#  'ROW': 133,
#  'ORF': 134,
#  'GTR': 135,
#  'BTM': 136,
#  'ERI': 137,
#  'CVG': 138,
#  'GRK': 139,
#  'CIC': 140,
#  'LAX': 141,
#  'BOI': 142,
#  'BFL': 143,
#  'MBS': 144,
#  'BRW': 145,
#  'PDX': 146,
#  'MCO': 147,
#  'DTW': 148,
#  'FSD': 149,
#  'MEI': 150,
#  'PSP': 151,
#  'OTZ': 152,
#  'MDW': 153,
#  'IND': 154,
#  'YUM': 155,
#  'LWB': 156,
#  'BUF': 157,
#  'LAS': 158,
#  'ANC': 159,
#  'EYW': 160,
#  'LSE': 161,
#  'TPA': 162,
#  'MLI': 163,
#  'DAB': 164,
#  'CMX': 165,
#  'CRP': 166,
#  'SUN': 167,
#  'EWN': 168,
#  'CLL': 169,
#  'GJT': 170,
#  'MIA': 171,
#  'FWA': 172,
#  'MSP': 173,
#  'HLN': 174,
#  'SAT': 175,
#  'SIT': 176,
#  'ILM': 177,
#  'BKG': 178,
#  'BET': 179,
#  'TEX': 180,
#  'MYR': 181,
#  'GSO': 182,
#  'ABI': 183,
#  'DFW': 184,
#  'GSP': 185,
#  'ATW': 186,
#  'BNA': 187,
#  'PHX': 188,
#  'OKC': 189,
#  'HNL': 190,
#  'LCH': 191,
#  'TWF': 192,
#  'GGG': 193,
#  'OAK': 194,
#  'SLC': 195,
#  'STX': 196,
#  'GEG': 197,
#  'ROA': 198,
#  'MFR': 199,
#  'ISP': 200,
#  'MOB': 201,
#  'FLL': 202,
#  'EWR': 203,
#  'BHM': 204,
#  'MLU': 205,
#  'BTV': 206,
#  'RST': 207,
#  'PNS': 208,
#  'SAN': 209,
#  'MRY': 210,
#  'ADQ': 211,
#  'BZN': 212,
#  'ECP': 213,
#  'PHF': 214,
#  'CAK': 215,
#  'DAL': 216,
#  'TUS': 217,
#  'CYS': 218,
#  'LEX': 219,
#  'SJU': 220,
#  'IDA': 221,
#  'SPI': 222,
#  'OTH': 223,
#  'AZO': 224,
#  'ORD': 225,
#  'HDN': 226,
#  'CEC': 227,
#  'SPS': 228,
#  'DRO': 229,
#  'OAJ': 230,
#  'BOS': 231,
#  'MOD': 232,
#  'MLB': 233,
#  'CLT': 234,
#  'OMA': 235,
#  'SGU': 236,
#  'VPS': 237,
#  'HTS': 238,
#  'RIC': 239,
#  'ACV': 240,
#  'COD': 241,
#  'JNU': 242,
#  'TOL': 243,
#  'RDD': 244,
#  'ASE': 245,
#  'SAV': 246,
#  'AGS': 247,
#  'SFO': 248,
#  'CLE': 249,
#  'EGE': 250,
#  'GUC': 251,
#  'BGR': 252,
#  'COU': 253,
#  'MEM': 254,
#  'PSC': 255,
#  'IPL': 256,
#  'SJT': 257,
#  'COS': 258,
#  'SYR': 259,
#  'TLH': 260,
#  'TYR': 261,
#  'BQK': 262,
#  'DHN': 263,
#  'LNK': 264,
#  'CSG': 265,
#  'CID': 266,
#  'MQT': 267,
#  'ALB': 268,
#  'MHK': 269,
#  'ICT': 270,
#  'SCC': 271,
#  'KTN': 272,
#  'SDF': 273,
#  'MAF': 274,
#  'IYK': 275,
#  'BTR': 276,
#  'CPR': 277,
#  'MFE': 278,
#  'JAC': 279,
#  'LYH': 280,
#  'CRW': 281,
#  'CWA': 282,
#  'MKG': 283,
#  'STT': 284,
#  'YAK': 285,
#  'PIA': 286,
#  'CMI': 287,
#  'TRI': 288,
#  'GFK': 289,
#  'WRG': 290,
#  'GUM': 291,
#  'HSV': 292}

# %%
airline_encoding = dict((j,i) for i,j in enumerate(set(data['Airline'])))

# %%
airline_encoding
# Out:
# {'B6': 0,
#  'FL': 1,
#  'OH': 2,
#  'XE': 3,
#  'CO': 4,
#  'YV': 5,
#  'EV': 6,
#  'MQ': 7,
#  'AS': 8,
#  'AA': 9,
#  'F9': 10,
#  'HA': 11,
#  'UA': 12,
#  'WN': 13,
#  'US': 14,
#  '9E': 15,
#  'DL': 16,
#  'OO': 17}

# %%
data['AirportFrom'] = data['AirportFrom'].map(airport_encoding)
data['AirportTo'] = data['AirportTo'].map(airport_encoding)

# %%
data
# Out:
#           Time  Length Airline  AirportFrom  AirportTo  DayOfWeek  Class
# Flight
# 2313.0  1296.0   141.0      DL           93         34          1      0
# 6948.0   360.0   146.0      OO          258        225          4      0
# 1247.0  1170.0   143.0      B6          231        234          3      0
# 31.0    1410.0   344.0      US           67        188          6      0
# 563.0    692.0    98.0      FL           86         93          4      0
# ...        ...     ...     ...          ...        ...        ...    ...
# 6973.0   530.0    72.0      OO          197         62          5      1
# 1264.0   560.0   115.0      WN          158         47          4      1
# 5209.0   827.0    74.0      EV          125         93          2      1
# 607.0    715.0    65.0      WN          130        157          4      1
# 6377.0   770.0    55.0      OO          277         47          2      1
#
# [539382 rows x 7 columns]

# %%
data['Airline'] = data['Airline'].map(airline_encoding)

# %%
data.head()
# Out:
#           Time  Length  Airline  AirportFrom  AirportTo  DayOfWeek  Class
# Flight
# 2313.0  1296.0   141.0       16           93         34          1      0
# 6948.0   360.0   146.0       17          258        225          4      0
# 1247.0  1170.0   143.0        0          231        234          3      0
# 31.0    1410.0   344.0       14           67        188          6      0
# 563.0    692.0    98.0        1           86         93          4      0

# %%
y = data['Class']

# %%
y
# Out:
# Flight
# 2313.0    0
# 6948.0    0
# 1247.0    0
# 31.0      0
# 563.0     0
#          ..
# 6973.0    1
# 1264.0    1
# 5209.0    1
# 607.0     1
# 6377.0    1
# Name: Class, Length: 539382, dtype: int64

# %%
data.drop('Class', axis=1, inplace=True)

# %%
data.head()
# Out:
#           Time  Length  Airline  AirportFrom  AirportTo  DayOfWeek
# Flight
# 2313.0  1296.0   141.0       16           93         34          1
# 6948.0   360.0   146.0       17          258        225          4
# 1247.0  1170.0   143.0        0          231        234          3
# 31.0    1410.0   344.0       14           67        188          6
# 563.0    692.0    98.0        1           86         93          4

# %%
from sklearn.model_selection import train_test_split

# %%
train_x, test_x, train_y, test_y = train_test_split(data, y)

# %%
print(train_x.shape, test_x.shape, train_y.shape, test_y.shape)
# Out:
# (404536, 6) (134846, 6) (404536,) (134846,)

# %%
from sklearn.linear_model import Perceptron

# %%
model = Perceptron()

# %%
model.fit(train_x, train_y)
# Out:
# Perceptron()

# %%
predicted = model.predict(test_x)

# %%
from sklearn.metrics import f1_score, precision_score, recall_score,accuracy_score

# %%
f1_score(predicted, test_y)
# Out:
# 0.0018648950164010857

# %%
recall_score(predicted, test_y)
# Out:
# 0.45901639344262296

# %%
precision_score(predicted, test_y)
# Out:
# 0.000934345541002753

# %%
accuracy_score(predicted, test_y)
# Out:
# 0.5554558533438144
